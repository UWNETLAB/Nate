# %%
import nate

# %%
mueller = nate.import_files('../data/mueller.txt')

# %%
sub_tags = ['PERSON', 'NORP', 'FAC', 'ORG', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW']
obj_tags = ['PERSON', 'NORP', 'FAC', 'ORG', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW']

# %%
sub_tags = ['PERSON']
obj_tags = ['PERSON']

# %%
mueller.svo(sub_tags, obj_tags)

# %%
mueller.svo(NER_tags)

# %%
mueller.svo(sub_tags, obj_tags)

# %%
df = mueller.svo(sub_tags, obj_tags, to_df=True)

# %%
df.head(75)
# Out:
#     doc_id  sent_id                                           sentence  \
# 0        0      353  (Candidate, Trump, signed, a Letter of Intent ...
# 1        0      358  (Immediately, upon, his, return, to, London, f...
# 2        0      402  (Incoming, National, Security, Advisor, Michae...
# 3        0      405  (The next day, ,, on, December 31, 2016, ,, Ki...
# 4        0      413  (The, investigation, continued, under, then, -...
# ..     ...      ...                                                ...
# 70       0    26284  (After, Lewandowski, told, Papadopoulos, to, ”...
# 71       0    26284  (After, Lewandowski, told, Papadopoulos, to, ”...
# 72       0    26290  (The, email, stated, that, ”, [, t]he, Russian...
# 73       0    26294  (*, George Papadopoulos, (, far, right, ), and...
# 74       0    26296  (The, pre, -, summit, messages, included, a, J...
#
#                                                   svo  \
# 0   (Candidate Trump, signed, a Letter of Intent f...
# 1                        (Mifsud, told, Papadopoulos)
# 2   (Advisor Michael Flynn, called, Ambassador Ser...
# 3                              (Flynn, call, Kislyak)
# 4                      (Comey, fire, President Trump)
# ..                                                ...
# 70                  (Lewandowski, told, Papadopoulos)
# 71                    (Papadopoulos, emailed, Clovis)
# 72     (meetings.478 Papadopoulos, told, Lewandowski)
# 73    (George Papadopoulos right, discussing, Russia)
# 74                    (Phares, meeting, Papadopoulos)
#
#                       subject        verb  \
# 0             Candidate Trump      signed
# 1                      Mifsud        told
# 2       Advisor Michael Flynn      called
# 3                       Flynn        call
# 4                       Comey        fire
# ..                        ...         ...
# 70                Lewandowski        told
# 71               Papadopoulos     emailed
# 72  meetings.478 Papadopoulos        told
# 73  George Papadopoulos right  discussing
# 74                     Phares     meeting
#
#                                        object
# 0   a Letter of Intent for Trump Tower Moscow
# 1                                Papadopoulos
# 2                   Ambassador Sergey Kislyak
# 3                                     Kislyak
# 4                             President Trump
# ..                                        ...
# 70                               Papadopoulos
# 71                                     Clovis
# 72                                Lewandowski
# 73                                     Russia
# 74                               Papadopoulos
#
# [75 rows x 7 columns]

# %%
df.head(75)
# Out:
#     doc_id  sent_id                                           sentence  \
# 0        0      353  Candidate Trump signed a Letter of Intent for ...
# 1        0      358  Immediately upon his return to London from tha...
# 2        0      402  Incoming National Security Advisor Michael Fly...
# 3        0      405  The next day, on December 31, 2016, Kislyak ca...
# 4        0      413  The investigation continued under then-Directo...
# ..     ...      ...                                                ...
# 70       0    26284  After Lewandowski told Papadopoulos to ”connec...
# 71       0    26284  After Lewandowski told Papadopoulos to ”connec...
# 72       0    26290  The email stated that ”[t]he Russian ministry ...
# 73       0    26294  *George Papadopoulos (far right) and Sam Clovi...
# 74       0    26296  The pre-summit messages included a July 11, 20...
#
#                                                   svo  \
# 0   (Candidate Trump, signed, a Letter of Intent f...
# 1                        (Mifsud, told, Papadopoulos)
# 2   (Advisor Michael Flynn, called, Ambassador Ser...
# 3                              (Flynn, call, Kislyak)
# 4                      (Comey, fire, President Trump)
# ..                                                ...
# 70                  (Lewandowski, told, Papadopoulos)
# 71                    (Papadopoulos, emailed, Clovis)
# 72     (meetings.478 Papadopoulos, told, Lewandowski)
# 73    (George Papadopoulos right, discussing, Russia)
# 74                    (Phares, meeting, Papadopoulos)
#
#                       subject sub_type        verb  \
# 0             Candidate Trump   PERSON      signed
# 1                      Mifsud      GPE        told
# 2       Advisor Michael Flynn   PERSON      called
# 3                       Flynn   PERSON        call
# 4                       Comey   PERSON        fire
# ..                        ...      ...         ...
# 70                Lewandowski   PERSON        told
# 71               Papadopoulos   PERSON     emailed
# 72  meetings.478 Papadopoulos   PERSON        told
# 73  George Papadopoulos right   PERSON  discussing
# 74                     Phares      ORG     meeting
#
#                                        object     obj_type
# 0   a Letter of Intent for Trump Tower Moscow  WORK_OF_ART
# 1                                Papadopoulos       PERSON
# 2                   Ambassador Sergey Kislyak       PERSON
# 3                                     Kislyak       PERSON
# 4                             President Trump          ORG
# ..                                        ...          ...
# 70                               Papadopoulos       PERSON
# 71                                     Clovis          GPE
# 72                                Lewandowski       PERSON
# 73                                     Russia          GPE
# 74                               Papadopoulos       PERSON
#
# [75 rows x 9 columns]

# %%
df.to_csv('test4.csv')

# %%
len(df)

# %%
df[['subject', 'verb', 'object']] = pd.DataFrame(df['svo'].tolist(), index=df.index)
