# %%
import nate

# %%
mueller = nate.import_files('../data/mueller.txt')

# %%
NER_tags = ['PERSON', 'NORP', 'FAC', 'ORG', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW']

# %%
NER_tags = ['PERSON']

# %%
mueller.svo(NER_tags)
# Out:
# [[('candidate Donald J. Trump', 'favor', 'a media campaign'),
#   ('candidate Hillary Clinton', 'disparage', 'a media campaign'),
#   ('candidate Clinton', 'disparage', 'a operation'),
#   ('candidate Trump', 'support', 'the same time'),
#   ('chairman John Podesta',
#    'include',
#    'the email accounts of Clinton Campaign volunteers'),
#   ('Hillary', 'incriminate', 'official documents'),
#   ('Ambassador Sergey Kislyak', 'call', 'Advisor Michael Flynn'),
#   ('Flynn', 'call', 'Kislyak'),
#   ('Papadopoulos', 'tell', 'the professor'),
#   ('Manafort ( crimes ; allegations ;', 'involve', 'allegations'),
#   ('Michael Flynn , National Security Advisor', 'involve', 'allegations'),
#   ('Paul Manafort', 'include', 'subjects of ,'),
#   ('Hillary Clinton', 'criticize', 'any opportunity'),
#   ('Hillary Clinton', 'criticize', 'posts'),
#   ('candidate Clinton', 'depict', 'an advertisement'),
#   ('Clinton', 'feature', 'advertisements'),
# ...
